# %%
from pathlib import Path
from typing import List, Tuple, Dict

# Wav Features and Visualization
import librosa
import IPython.display as ipd
# Basics
import numpy as np
import pandas as pd
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Machine Learning
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # View Data

# %%
def load_wav(path: str, sample_rate: int) -> np.ndarray:
    waveform, _ = librosa.load(path, sr=sample_rate)
    return waveform


def extract_features(
        file_path: str, 
        sample_rate: int=22050,
        hop_length: int=220,
        n_fft: int=2048,
        n_frames_per_example: int=1
    ) -> List[np.ndarray]:
    
    waveform = load_wav(file_path, sample_rate=sample_rate)
    
    spectrogram = librosa.feature.melspectrogram(
        waveform, n_fft=n_fft, hop_length=hop_length
    )
    
    spectrogram = np.log(1e-20 + np.abs(spectrogram ** 2))
    
    n_examples = spectrogram.shape[1] // n_frames_per_example
    
    return [
        spectrogram[
            :,
            i*n_frames_per_example:(i+1) * n_frames_per_example
        ].reshape(1, -1)
        for i in range(n_examples)
    ]

# %%
path = 'data/train/train/classical/1429195257218202828.wav'
# 1161154212832220511.wav
# 1429195257218202828.wav
n_frames_per_example = 15
axis = False

ipd.display(ipd.Audio(path))

features = extract_features(path, n_frames_per_example=n_frames_per_example)

features = [
    feature.reshape(-1, n_frames_per_example)
    for feature in features
]

plt.figure(figsize=(20,5))
plt.title('Spectrogram')
plt.imshow(np.hstack(features), cmap='plasma')
if axis:
    plt.xlabel('seconds')
    plt.ylabel('mel')
else:
    plt.axis('off')
plt.savefig('spectrogram.png', dpi=200)
plt.show()

plt.figure(figsize=(20,5))
for i, feature in enumerate(features):
    plt.subplot(1, len(features) + 1, i + 1)
    plt.imshow(feature, cmap='plasma')
    plt.axis('off')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.16705322 -0.16708374 -0.15670776 ...  0.1411438   0.17166138
#   0.19277954] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(

# %% [markdown]
# # Prepare Train Dataset

# %%
def load_folder_data(
        path: Path, 
        train: bool, 
        params: Dict[str, int]
    ) -> Tuple[
        List[List[np.ndarray]], 
        List[str], 
        List[str]
    ]:
    
    features: List[List[np.ndarray]] = []
    labels: List[str] = []
    file_names: List[str] = list(path.rglob('*.wav'))

    for file_path in file_names:
        
        file_features = extract_features(file_path, **params)

        features.append(file_features)
        
        if train:
            class_name = file_path.parent.name
            labels.append([class_name] * len(file_features))
    
    return features, labels, file_names

# %%
params = {
    'sample_rate': 22050,
    'hop_length': 220,
    'n_fft': 2048,
    'n_frames_per_example': 1
}
train_path = Path('data/train/train')
test_path = Path('data/test/test')
SEED = 42
test_size = 0.1

# %%
class_names = [folder.name for folder in train_path.iterdir()]

class_name2id = {
    class_name: class_id 
    for class_id, class_name in enumerate(class_names)
}

features, labels, file_names = load_folder_data(train_path, train=True, params=params)

labels = [
    [class_name2id[label] for label in label_list]
    for label_list in labels
]
# Out:
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02392578 -0.02246094 -0.01403809 ... -0.17843628 -0.20986938
#  -0.19522095] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.09414673 -0.12319946 -0.11471558 ... -0.12991333 -0.13250732
#  -0.1272583 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.09072876 -0.08175659 -0.06817627 ... -0.27444458 -0.30548096
#  -0.3288269 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.26913452  0.41671753  0.42752075 ...  0.04135132 -0.00537109
#  -0.03704834] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.06799316 0.1187439  0.07827759 ... 0.24020386 0.23190308 0.15148926] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02584839  0.02502441  0.02331543 ... -0.02938843 -0.04519653
#  -0.06149292] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.6355896  0.6508789  0.6361084  ... 0.57403564 0.64056396 0.52059937] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02597046 -0.0592041  -0.06451416 ...  0.05743408  0.03189087
#   0.02697754] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.25860596 -0.2253418  -0.11022949 ... -0.30386353 -0.25357056
#  -0.22290039] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.48529053 -0.20883179 -0.61154175 ... -0.19250488 -0.04632568
#  -0.02935791] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.2828369  -0.26727295 -0.38168335 ...  0.11917114  0.05664062
#   0.10757446] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.21200562 0.1355896  0.14324951 ... 0.07351685 0.10681152 0.06872559] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.22702026 -0.14144897  0.01495361 ... -0.1791687  -0.1513977
#   0.00958252] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.13345337 0.15600586 0.16131592 ... 0.35513306 0.3132019  0.3357849 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.08276367  0.2010498   0.05413818 ... -0.17877197 -0.27011108
#  -0.21694946] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.6737671   0.649353    0.5965576  ... -0.17929077 -0.19317627
#  -0.2638855 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.11691284  0.11346436  0.10693359 ... -0.00140381 -0.01428223
#  -0.02172852] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01141357 -0.11239624 -0.24490356 ... -0.59576416 -0.62371826
#  -0.3468933 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02947998 -0.03179932 -0.02346802 ...  0.02310181  0.03262329
#   0.03320312] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.02966309 0.01013184 0.00143433 ... 0.10900879 0.09738159 0.09265137] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.31463623 0.20532227 0.07983398 ... 0.09378052 0.08630371 0.09048462] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02975464 -0.01171875  0.02658081 ... -0.01147461  0.0201416
#   0.03079224] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.23516846 -0.22436523 -0.18896484 ... -0.03918457 -0.07015991
#  -0.00595093] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.13070679 0.2121582  0.1465149  ... 0.40881348 0.3882141  0.3768921 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.10681152 0.13613892 0.07461548 ... 0.21212769 0.35113525 0.41186523] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.87991333  0.87615967  0.8493042  ... -0.1920166  -0.09790039
#  -0.01419067] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.12442017  0.1519165   0.14926147 ... -0.14343262 -0.17300415
#  -0.22210693] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.27374268  0.33773804  0.50180054 ...  0.08078003  0.03656006
#  -0.00473022] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0027771   0.03500366  0.03826904 ... -0.22653198 -0.28067017
#  -0.27246094] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.353302   -0.26156616 -0.04418945 ...  0.06109619  0.03314209
#   0.15585327] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.14355469  0.14834595  0.13696289 ... -0.19689941 -0.19677734
#  -0.1852417 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01669312  0.00244141 -0.00204468 ... -0.2010498  -0.24124146
#  -0.30377197] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.00836182 0.00958252 0.02410889 ... 0.20928955 0.14657593 0.03213501] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.19592285 -0.23287964 -0.06930542 ... -0.19158936 -0.33340454
#  -0.47283936] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0557251  -0.11437988 -0.25091553 ...  0.09701538  0.18048096
#   0.2524414 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.15966797 -0.1555481  -0.17175293 ... -0.13272095  0.06317139
#  -0.28677368] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.16625977 0.19110107 0.19689941 ... 0.07284546 0.1826477  0.24746704] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.087677   -0.09674072 -0.08206177 ...  0.07058716  0.06826782
#  -0.04260254] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.12841797 -0.10949707 -0.06723022 ... -0.02114868 -0.05224609
#   0.19064331] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.26013184 -0.2746582  -0.11398315 ...  0.0213623  -0.20166016
#  -0.17874146] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.05032349 0.02005005 0.05480957 ... 0.10107422 0.0869751  0.11828613] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.25302124 -0.41101074 -0.35284424 ...  0.01037598  0.01290894
#   0.04229736] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.14031982 0.11257935 0.12649536 ... 0.14816284 0.14144897 0.1388855 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.53552246 -0.5252075  -0.53793335 ...  0.868103    0.87176514
#   0.8786621 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.04211426  0.03729248  0.0246582  ...  0.03335571 -0.22735596
#   0.1572876 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.20455933 -0.1864624  -0.24160767 ... -0.05722046 -0.03991699
#  -0.02194214] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.00958252 -0.00308228  0.03475952 ...  0.02578735  0.04278564
#   0.0519104 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.03448486 0.04812622 0.06427002 ... 0.03613281 0.05639648 0.06488037] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.09570312 0.10333252 0.03234863 ... 0.04489136 0.08596802 0.09359741] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.17526245 -0.18371582 -0.21450806 ...  0.45651245  0.11087036
#   0.26382446] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.14431763 0.13769531 0.15060425 ... 0.09762573 0.12768555 0.11428833] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.92593384 -0.9970398  -0.54678345 ...  0.00424194  0.00717163
#   0.00253296] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02734375 -0.02929688 -0.0246582  ...  0.07861328  0.08190918
#   0.08163452] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.67111206  0.71435547  0.6657715  ... -0.09240723 -0.11807251
#  -0.11489868] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.21170044 -0.16766357 -0.1489563  ... -0.09313965 -0.11938477
#  -0.13256836] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.32717896 -0.33862305 -0.33563232 ... -0.09484863 -0.08151245
#  -0.08023071] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02572632  0.02709961  0.09375    ...  0.26693726 -0.03961182
#   0.28460693] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.19973755  0.12902832  0.01675415 ... -0.2644043  -0.21365356
#  -0.24084473] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.23562622 0.24151611 0.29864502 ... 0.37768555 0.3447876  0.33670044] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.08947754 -0.09341431 -0.08700562 ...  0.21798706  0.12036133
#   0.39898682] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.03414917  0.05419922  0.07122803 ...  0.07312012 -0.09533691
#  -0.15405273] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.10717773  0.16119385  0.28582764 ...  0.04736328 -0.04095459
#  -0.26296997] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.6204529   0.56799316  0.566803   ... -0.17984009 -0.14035034
#  -0.23065186] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01409912 -0.00918579 -0.00689697 ... -0.14489746 -0.05300903
#  -0.1456604 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-2.5473022e-01 -2.4414062e-04 -3.7933350e-02 ...  4.7753906e-01
#   4.4412231e-01  4.2062378e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.04040527 -0.1161499   0.04275513 ...  0.0227356   0.06872559
#   0.09707642] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.06787109  0.04498291  0.07388306 ...  0.09060669  0.00280762
#  -0.07568359] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.07800293 -0.03762817  0.12661743 ... -0.44021606 -0.46133423
#  -0.2532959 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02853394 -0.13726807 -0.08892822 ... -0.11755371 -0.17666626
#  -0.21542358] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.07223511 -0.06262207 -0.05566406 ... -0.02069092 -0.02175903
#  -0.02142334] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.24822998 -0.19805908 -0.15863037 ...  0.1986084   0.1619873
#   0.22927856] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.13919067  0.14883423  0.13644409 ... -0.13345337 -0.1567688
#  -0.1784668 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01690674 -0.01858521  0.00775146 ...  0.2336731   0.24279785
#   0.19561768] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.10757446 -0.10955811 -0.10159302 ...  0.02264404  0.01159668
#   0.02041626] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.07894897 0.309021   0.04953003 ... 0.00387573 0.00402832 0.03652954] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.24581909 -0.18185425  0.12420654 ... -0.21453857  0.12194824
#  -0.16864014] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.20736694 -0.15759277 -0.24346924 ... -0.32980347 -0.33657837
#  -0.355896  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.25567627  0.24008179  0.27783203 ... -0.11486816 -0.08935547
#  -0.06106567] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.06192017  0.05178833  0.14974976 ... -0.13348389 -0.12548828
#  -0.13760376] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.13842773  0.14178467  0.06878662 ... -0.3949585  -0.25976562
#  -0.47827148] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.17272949 0.37005615 0.34762573 ... 0.18307495 0.04205322 0.01196289] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.09460449 -0.11404419 -0.13571167 ...  0.14477539  0.06466675
#  -0.00967407] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01647949  0.00341797  0.00656128 ...  0.34884644  0.37771606
#   0.38842773] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0887146  -0.05932617 -0.17105103 ...  0.30636597  0.2775879
#   0.21557617] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.10958862 0.12200928 0.13058472 ... 0.01086426 0.07305908 0.09368896] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.28414917 -0.26211548 -0.22943115 ... -0.01989746  0.03503418
#  -0.0357666 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.18334961  0.17965698  0.18215942 ... -0.31433105 -0.31100464
#  -0.3477478 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.38671875  0.40148926  0.35647583 ... -0.01135254 -0.04364014
#  -0.04016113] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.12078857 -0.11590576 -0.11437988 ...  0.04721069  0.04211426
#   0.03079224] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01782227 -0.09634399 -0.07501221 ... -0.17459106 -0.1803894
#  -0.1338501 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.03536987 -0.02868652 -0.04281616 ...  0.01541138  0.03311157
#   0.04187012] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0645752  -0.02124023 -0.0100708  ...  0.05044556  0.03057861
#   0.00653076] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.01651001 -0.01089478  0.01086426 ... -0.6836853  -0.8916626
#  -0.81655884] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.07821655  0.07501221  0.07330322 ... -0.01159668  0.01443481
#   0.03869629] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.02978516 0.01412964 0.02655029 ... 0.02770996 0.02752686 0.02670288] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.01251221 0.01947021 0.02938843 ... 0.21539307 0.13745117 0.11013794] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.14318848  0.19198608 -0.19174194 ... -0.02990723  0.08795166
#   0.08981323] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.04879761 -0.0602417  -0.07363892 ...  0.02081299  0.01928711
#   0.01852417] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.01806641 -0.00823975  0.02716064 ... -0.41989136 -0.44473267
#  -0.47616577] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.42410278 -0.10186768  0.09939575 ...  0.14239502  0.26086426
#  -0.02856445] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.20129395  0.19628906  0.270813   ... -0.23797607 -0.2111206
#  -0.17614746] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.40185547 -0.44418335 -0.40722656 ... -0.12234497 -0.1539917
#  -0.16168213] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.2848816  -0.3175354  -0.2675476  ...  0.5930481   0.05151367
#   0.23168945] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.         -0.02029419 -0.02911377 ... -0.00717163 -0.00631714
#  -0.00305176] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.4803772   0.5096741   0.59375    ... -0.06137085 -0.10638428
#  -0.18197632] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.09970093 -0.10150146 -0.1078186  ...  0.23608398  0.22271729
#   0.19869995] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.25897217  0.2852478   0.2177124  ... -0.05679321 -0.05532837
#  -0.06289673] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01776123  0.25634766  0.09387207 ... -0.09634399 -0.10275269
#  -0.10302734] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.09863281 -0.10217285 -0.0982666  ... -0.08047485 -0.09170532
#  -0.13412476] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02670288 -0.00241089  0.01980591 ... -0.04705811 -0.03067017
#  -0.03125   ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.00131226 -0.0255127   0.0239563  ...  0.13461304 -0.07577515
#  -0.11886597] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02474976 -0.01315308 -0.2952881  ... -0.05227661  0.00747681
#   0.04296875] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-8.1481934e-03  3.0212402e-03  2.4414062e-04 ... -1.7294312e-01
#  -2.1237183e-01 -2.9162598e-01] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.4732666  -0.5097351  -0.5383301  ...  0.15908813  0.18240356
#   0.10125732] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.19268799 -0.11242676 -0.16552734 ...  0.03033447  0.08920288
#   0.0145874 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.3808899  -0.26608276 -0.27822876 ... -0.23913574 -0.11749268
#   0.12408447] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.5817566  0.72784424 0.8614807  ... 0.27874756 0.30447388 0.32589722] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.138031    0.19784546  0.3857422  ... -0.23565674 -0.25585938
#  -0.19787598] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.04608154 -0.1244812   0.1607666  ... -0.00222778  0.00210571
#   0.0043335 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.52545166 -0.552063   -0.75286865 ...  0.14013672  0.27200317
#   0.1862793 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.09118652 -0.34817505  0.14541626 ... -0.04821777 -0.00387573
#   0.12695312] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.40875244  0.47790527  0.4942932  ... -0.08187866  0.00656128
#   0.1244812 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.3692627  0.5821228  0.44577026 ... 0.0055542  0.07229614 0.09786987] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.177948    0.15396118  0.14083862 ... -0.00479126 -0.0032959
#  -0.00506592] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.22091675 -0.21807861 -0.20233154 ... -0.29730225  0.07705688
#   0.32666016] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.23394775  0.19836426  0.18096924 ... -0.26028442  0.0072937
#   0.11917114] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.11218262 -0.07196045 -0.10198975 ... -0.10604858 -0.16680908
#  -0.1899414 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.04943848 -0.0965271  -0.1524353  ... -0.07901001 -0.11175537
#  -0.1178894 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0015564  -0.00149536 -0.01177979 ... -0.0770874  -0.0741272
#  -0.07116699] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.08792114  0.06573486  0.06283569 ... -0.25463867 -0.24520874
#  -0.23660278] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.08609009 -0.06643677  0.01135254 ... -0.0536499  -0.06451416
#  -0.05618286] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.1592102  0.11968994 0.11264038 ... 0.6398926  0.68795776 0.5956726 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.15304565 0.18643188 0.20394897 ... 0.11126709 0.2954712  0.31808472] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.33654785 -0.19863892 -0.18423462 ... -0.0390625  -0.01998901
#   0.05389404] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.29977417 -0.20874023 -0.16946411 ...  0.04354858  0.04284668
#   0.12194824] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.22912598  0.00354004 -0.24667358 ...  0.00518799  0.027771
#   0.02947998] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.08575439 -0.16464233 -0.09951782 ... -0.10882568 -0.13720703
#  -0.0965271 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.20751953 -0.08084106 -0.06347656 ...  0.06616211  0.1343689
#   0.02380371] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.10748291  0.11773682  0.11843872 ...  0.01303101 -0.0279541
#   0.00744629] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.18099976 -0.14590454 -0.11776733 ...  0.4310913  -0.5367737
#   0.41186523] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.04333496 -0.03140259 -0.5536804  ... -0.14678955 -0.24630737
#  -0.31506348] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.19750977 -0.19100952 -0.14089966 ... -0.0166626   0.01629639
#  -0.01055908] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.28756714  0.06210327 -0.13327026 ...  0.02761841 -0.2024231
#  -0.23147583] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.17733765 -0.20602417 -0.23580933 ...  0.31033325  0.5479126
#   0.530426  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.09240723  0.10671997  0.1144104  ... -0.07180786 -0.10803223
#  -0.14764404] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02835083 -0.05444336  0.1098938  ... -0.13076782 -0.1253357
#  -0.24523926] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.26916504 -0.24664307 -0.1857605  ... -0.42861938 -0.39743042
# ...
#  -0.00808716] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01223755 -0.0163269  -0.02328491 ...  0.06018066  0.0451355
#   0.04650879] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.1472168  0.14318848 0.14523315 ... 0.00686646 0.00939941 0.012146  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.03747559 -0.04870605 -0.04602051 ...  0.02331543  0.02670288
#   0.02478027] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.30337524 -0.31280518 -0.32104492 ... -0.04971313 -0.04119873
#  -0.04824829] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.00964355  0.00604248  0.00375366 ... -0.01278687 -0.01281738
#  -0.0071106 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.08331299 0.14602661 0.14703369 ... 0.05456543 0.06695557 0.09222412] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.00686646  0.03695679  0.07254028 ... -0.09674072 -0.02243042
#   0.02703857] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.10922241  0.03134155 -0.02609253 ... -0.08615112 -0.07125854
#  -0.09387207] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.03915405 -0.06048584 -0.07571411 ...  0.06802368  0.07577515
#   0.08007812] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0869751  -0.0847168  -0.0796814  ... -0.08041382 -0.08328247
#  -0.08828735] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.08016968  0.05609131  0.13909912 ...  0.00073242 -0.01473999
#   0.02893066] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.04379272 0.06262207 0.0418396  ... 0.1184082  0.12121582 0.13070679] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.06149292 -0.06411743 -0.07131958 ...  0.02023315  0.02279663
#   0.025177  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.04696655 0.04281616 0.03723145 ... 0.00894165 0.01260376 0.01647949] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.19540405 -0.1902771  -0.1362915  ...  0.05593872  0.02703857
#   0.01699829] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.105896    0.08059692  0.04608154 ...  0.03042603 -0.01751709
#   0.03302002] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.09069824  0.13882446  0.08270264 ...  0.01419067  0.01083374
#  -0.00427246] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.28152466 -0.36090088 -0.401886   ... -0.03619385 -0.03845215
#  -0.04354858] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.04949951 -0.02099609 -0.02392578 ...  0.04800415  0.06881714
#   0.07229614] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02954102 -0.0269165  -0.03131104 ... -0.03479004 -0.03152466
#   0.01153564] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.0479126   0.11972046  0.20477295 ... -0.2869873  -0.13153076
#  -0.05700684] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.25308228 -0.20803833 -0.09994507 ... -0.08447266 -0.0307312
#  -0.07965088] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01052856 -0.00643921 -0.00363159 ... -0.00814819 -0.01251221
#  -0.01208496] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02813721  0.04934692  0.10113525 ... -0.12359619 -0.07144165
#  -0.02093506] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.06359863 -0.03796387 -0.04324341 ... -0.05651855 -0.04718018
#  -0.04373169] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.12200928  0.22439575  0.19662476 ... -0.00384521 -0.0065918
#  -0.01052856] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.00488281  0.00143433 -0.00039673 ...  0.00308228  0.01107788
#   0.01928711] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.04534912 -0.01864624  0.01934814 ... -0.0007019   0.00039673
#   0.01379395] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01071167 -0.01391602 -0.00509644 ... -0.00238037  0.00143433
#   0.00222778] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.06784058  0.05834961  0.03375244 ... -0.10018921 -0.03375244
#  -0.02090454] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.03485107 -0.04220581  0.00183105 ... -0.00500488  0.01901245
#   0.0289917 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.00131226  0.01934814  0.04595947 ...  0.02560425  0.02203369
#   0.02124023] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.07473755 -0.13851929 -0.16339111 ...  0.20507812  0.13897705
#   0.08010864] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.0821228  -0.09014893 -0.11203003 ...  0.02261353  0.02255249
#   0.0279541 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.01144409 0.01156616 0.00744629 ... 0.07199097 0.08505249 0.10488892] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.08877563  0.09716797  0.08218384 ... -0.03881836 -0.04559326
#  -0.0536499 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.02276611 0.03561401 0.0291748  ... 0.02786255 0.02822876 0.02810669] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.25842285 -0.28970337 -0.2909851  ...  0.3183899   0.319458
#   0.31756592] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.00689697 -0.0350647  -0.07888794 ...  0.11160278  0.14779663
#   0.23782349] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.01730347 -0.02087402 -0.01678467 ... -0.01828003 -0.01971436
#  -0.01361084] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02401733  0.02322388  0.02368164 ... -0.02633667 -0.03216553
#  -0.03564453] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.08389282 -0.08068848 -0.0980835  ... -0.08886719 -0.06826782
#  -0.05126953] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.02548218 -0.0357666  -0.04550171 ... -0.05413818 -0.05636597
#  -0.05599976] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.00366211 -0.07833862 -0.15301514 ... -0.515625   -0.3591919
#  -0.28500366] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.01647949  0.02920532  0.03012085 ...  0.00701904 -0.02218628
#  -0.0272522 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[ 0.02993774 -0.00650024  0.00790405 ...  0.16293335  0.00460815
#  -0.01898193] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[-0.00335693 -0.00531006 -0.02548218 ... -0.07745361 -0.08032227
#  -0.07821655] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(
# /var/folders/04/7ltt_n9d1z14zmw8_ky4jc5h0000gn/T/ipykernel_67625/584613446.py:16: FutureWarning: Pass y=[0.06311035 0.07244873 0.07611084 ... 0.0201416  0.02148438 0.01983643] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectrogram = librosa.feature.melspectrogram(

# %%
features_train, features_test, labels_train, labels_test, files_train, files_test = \
train_test_split(
    features, labels, file_names, test_size=test_size, random_state=SEED
)

# %%
X_train = np.vstack([x for list_ in features_train for x in list_])
y_train = np.array([x for list_ in labels_train for x in list_])

# %%
X_train
# Out:
# array([[ -5.9302974 ,  -0.04703975,   3.3783612 , ..., -19.931154  ,
#         -20.140862  , -20.182308  ],
#        [ -4.5215125 ,   0.89560294,   4.47439   , ..., -20.390568  ,
#         -20.61092   , -20.65167   ],
#        [ -3.6911092 ,   1.0165417 ,   4.859222  , ..., -21.882559  ,
#         -22.132235  , -22.172745  ],
#        ...,
#        [  3.3239827 ,   8.743607  ,   9.729862  , ..., -18.311962  ,
#         -18.70252   , -18.746477  ],
#        [  4.4808607 ,   9.1362915 ,   9.389581  , ..., -16.590717  ,
#         -16.722683  , -16.756823  ],
#        [  4.790876  ,   8.766502  ,   8.342966  , ..., -15.856491  ,
#         -15.908391  , -15.940667  ]], dtype=float32)

# %%
# %%time

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', DecisionTreeClassifier())
]).fit(X_train, y_train)

# %% [markdown]
# # Interpretation

# %%
test_id = 890

predictions = pipe.predict_proba(np.vstack(features_train[test_id]))

plt.figure(figsize=(18,6))
plt.title(files_train[test_id])
wave_form = load_wav(files_train[test_id], sample_rate=params['sample_rate'])
time_axis = [x / params['sample_rate'] for x in range(wave_form.size)]
plt.plot(time_axis, wave_form)
plt.xlabel('seconds')
plt.show()

ipd.display(ipd.Audio(files_train[test_id]))
plt.figure(figsize=(18,6))
plt.subplot(121)
plt.title('Genre Probability by Frame')
sns.heatmap(
    predictions.T,
    yticklabels=class_names
)

plt.subplot(122)
plt.title('Averaged Probability')
plt.barh(class_names, predictions.mean(0))
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Confusion matrix

# %%
def plot_conf_matrix(y_test: np.ndarray, y_pred: np.ndarray, class_names: List[str], annot: bool=False) -> None:
    
    plt.figure(figsize=(8,6))
    plt.title(f"Accuracy: {(y_test == y_pred).mean():.2f}")
    sns.heatmap(
        confusion_matrix(y_test, y_pred), 
        xticklabels=class_names, 
        yticklabels=class_names,
        linewidths=.5,
        annot=annot
    )
    plt.show()

# %% [markdown]
# ### by frame

# %%
X_test = np.vstack([
    feature for feature_list in features_test 
    for feature in feature_list
])

y_test = np.array([label for label_list in labels_test for label in label_list])

y_pred = pipe.predict(X_test)

plot_conf_matrix(y_pred, y_test, class_names)

# %% [markdown]
# ### by record

# %%
y_pred = np.array([
    pipe.predict_proba(np.vstack(feature_list)).mean(0).argmax()
    for feature_list in features_test
])

y_test = np.array([label_list[0] for label_list in labels_test])

plot_conf_matrix(y_pred, y_test, class_names, annot=True)

# %% [markdown]
# # Test

# %%
test_features, _, test_pathes = load_folder_data(test_path, train=False, params=params)

# %%
predictions = [
    class_names[
        pipe.predict_proba(
            np.vstack(test_feature)
        ).mean(0).argmax()
    ]
    for test_feature in test_features
]

# %%
(
    pd.DataFrame({
        'index': [test_wav_path.name for test_wav_path in test_path.iterdir()],
        'genre': predictions
    })
    .to_csv('submit.csv', index=False)
)
